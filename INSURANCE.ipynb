# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("D:/Insurance Claim/car_insurance_claim.csv")

# %%
df
# Out:
#               ID  KIDSDRIV      BIRTH   AGE  HOMEKIDS   YOJ    INCOME PARENT1  \
# 0       63581743         0  16-Mar-39  60.0         0  11.0   $67,349      No
# 1      132761049         0  21-Jan-56  43.0         0  11.0   $91,449      No
# 2      921317019         0  18-Nov-51  48.0         0  11.0   $52,881      No
# 3      727598473         0  05-Mar-64  35.0         1  10.0   $16,039      No
# 4      450221861         0  05-Jun-48  51.0         0  14.0       NaN      No
# ...          ...       ...        ...   ...       ...   ...       ...     ...
# 10297   67790126         1  13-Aug-54  45.0         2   9.0  $164,669      No
# 10298   61970712         0  17-Jun-53  46.0         0   9.0  $107,204      No
# 10299  849208064         0  18-Jun-51  48.0         0  15.0   $39,837      No
# 10300  627828331         0  12-Dec-48  50.0         0   7.0   $43,445      No
# 10301  680381960         0  27-Feb-47  52.0         0  11.0   $53,235      No
#
#        HOME_VAL MSTATUS  ...     CAR_TYPE RED_CAR OLDCLAIM  CLM_FREQ REVOKED  \
# 0            $0    z_No  ...      Minivan     yes   $4,461         2      No
# 1      $257,252    z_No  ...      Minivan     yes       $0         0      No
# 2            $0    z_No  ...          Van     yes       $0         0      No
# 3      $124,191     Yes  ...        z_SUV      no  $38,690         2      No
# 4      $306,251     Yes  ...      Minivan     yes       $0         0      No
# ...         ...     ...  ...          ...     ...      ...       ...     ...
# 10297  $386,273     Yes  ...      Minivan      no       $0         0      No
# 10298  $332,591     Yes  ...  Panel Truck      no       $0         0      No
# 10299  $170,611     Yes  ...        z_SUV      no       $0         0      No
# 10300  $149,248     Yes  ...      Minivan      no       $0         0      No
# 10301  $197,017     Yes  ...      Minivan      no       $0         0      No
#
#       MVR_PTS  CLM_AMT CAR_AGE CLAIM_FLAG             URBANICITY
# 0           3       $0    18.0          0    Highly Urban/ Urban
# 1           0       $0     1.0          0    Highly Urban/ Urban
# 2           2       $0    10.0          0    Highly Urban/ Urban
# 3           3       $0    10.0          0    Highly Urban/ Urban
# 4           0       $0     6.0          0    Highly Urban/ Urban
# ...       ...      ...     ...        ...                    ...
# 10297       2       $0    17.0          0    Highly Urban/ Urban
# 10298       0       $0     1.0          0    Highly Urban/ Urban
# 10299       0       $0     1.0          0    Highly Urban/ Urban
# 10300       0       $0    11.0          0    Highly Urban/ Urban
# 10301       0       $0     9.0          0  z_Highly Rural/ Rural
#
# [10302 rows x 27 columns]

# %%
df.shape
# Out:
# (10302, 27)

# %%
df.head()
# Out:
#           ID  KIDSDRIV      BIRTH   AGE  HOMEKIDS   YOJ   INCOME PARENT1  \
# 0   63581743         0  16-Mar-39  60.0         0  11.0  $67,349      No
# 1  132761049         0  21-Jan-56  43.0         0  11.0  $91,449      No
# 2  921317019         0  18-Nov-51  48.0         0  11.0  $52,881      No
# 3  727598473         0  05-Mar-64  35.0         1  10.0  $16,039      No
# 4  450221861         0  05-Jun-48  51.0         0  14.0      NaN      No
#
#    HOME_VAL MSTATUS  ... CAR_TYPE RED_CAR OLDCLAIM  CLM_FREQ REVOKED MVR_PTS  \
# 0        $0    z_No  ...  Minivan     yes   $4,461         2      No       3
# 1  $257,252    z_No  ...  Minivan     yes       $0         0      No       0
# 2        $0    z_No  ...      Van     yes       $0         0      No       2
# 3  $124,191     Yes  ...    z_SUV      no  $38,690         2      No       3
# 4  $306,251     Yes  ...  Minivan     yes       $0         0      No       0
#
#    CLM_AMT CAR_AGE CLAIM_FLAG           URBANICITY
# 0       $0    18.0          0  Highly Urban/ Urban
# 1       $0     1.0          0  Highly Urban/ Urban
# 2       $0    10.0          0  Highly Urban/ Urban
# 3       $0    10.0          0  Highly Urban/ Urban
# 4       $0     6.0          0  Highly Urban/ Urban
#
# [5 rows x 27 columns]

# %%
df.isna().sum()
# Out:
# ID              0
# KIDSDRIV        0
# BIRTH           0
# AGE             7
# HOMEKIDS        0
# YOJ           548
# INCOME        570
# PARENT1         0
# HOME_VAL      575
# MSTATUS         0
# GENDER          0
# EDUCATION       0
# OCCUPATION    665
# TRAVTIME        0
# CAR_USE         0
# BLUEBOOK        0
# TIF             0
# CAR_TYPE        0
# RED_CAR         0
# OLDCLAIM        0
# CLM_FREQ        0
# REVOKED         0
# MVR_PTS         0
# CLM_AMT         0
# CAR_AGE       639
# CLAIM_FLAG      0
# URBANICITY      0
# dtype: int64

# %%
ID              0 - drop
KIDSDRIV        0 #- drop
BIRTH           0 - drop
AGE             7 
HOMEKIDS        0 #- drop
YOJ           548
#Year Of Joining
INCOME        570
PARENT1         0
HOME_VAL      575
MSTATUS         0
GENDER          0
EDUCATION       0
OCCUPATION    665
TRAVTIME        0
CAR_USE         0
BLUEBOOK        0
#BOOK WITH PRICES
TIF             0
#Tax increment financing
CAR_TYPE        0
RED_CAR         0
OLDCLAIM        0
CLM_FREQ        0
REVOKED         0
MVR_PTS         0
CLM_AMT         0
CAR_AGE       639
CLAIM_FLAG      0
URBANICITY      0
# Out:
#   File "<ipython-input-54-a2d239199e78>", line 1
#     ID              0 - drop
#                     ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10302 entries, 0 to 10301
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10302 non-null  int64
#  1   KIDSDRIV    10302 non-null  int64
#  2   BIRTH       10302 non-null  object
#  3   AGE         10295 non-null  float64
#  4   HOMEKIDS    10302 non-null  int64
#  5   YOJ         9754 non-null   float64
#  6   INCOME      9732 non-null   object
#  7   PARENT1     10302 non-null  object
#  8   HOME_VAL    9727 non-null   object
#  9   MSTATUS     10302 non-null  object
#  10  GENDER      10302 non-null  object
#  11  EDUCATION   10302 non-null  object
#  12  OCCUPATION  9637 non-null   object
#  13  TRAVTIME    10302 non-null  int64
#  14  CAR_USE     10302 non-null  object
#  15  BLUEBOOK    10302 non-null  object
#  16  TIF         10302 non-null  int64
#  17  CAR_TYPE    10302 non-null  object
#  18  RED_CAR     10302 non-null  object
#  19  OLDCLAIM    10302 non-null  object
#  20  CLM_FREQ    10302 non-null  int64
#  21  REVOKED     10302 non-null  object
#  22  MVR_PTS     10302 non-null  int64
#  23  CLM_AMT     10302 non-null  object
#  24  CAR_AGE     9663 non-null   float64
#  25  CLAIM_FLAG  10302 non-null  int64
#  26  URBANICITY  10302 non-null  object
# dtypes: float64(3), int64(8), object(16)
# memory usage: 2.1+ MB

# %%
round(df.describe(),2).T
# Out:
#               count          mean           std      min          25%  \
# ID          10302.0  4.956631e+08  2.864675e+08  63175.0  244286856.0
# KIDSDRIV    10302.0  1.700000e-01  5.100000e-01      0.0          0.0
# AGE         10295.0  4.484000e+01  8.610000e+00     16.0         39.0
# HOMEKIDS    10302.0  7.200000e-01  1.120000e+00      0.0          0.0
# YOJ          9754.0  1.047000e+01  4.110000e+00      0.0          9.0
# TRAVTIME    10302.0  3.342000e+01  1.587000e+01      5.0         22.0
# TIF         10302.0  5.330000e+00  4.110000e+00      1.0          1.0
# CLM_FREQ    10302.0  8.000000e-01  1.150000e+00      0.0          0.0
# MVR_PTS     10302.0  1.710000e+00  2.160000e+00      0.0          0.0
# CAR_AGE      9663.0  8.300000e+00  5.710000e+00     -3.0          1.0
# CLAIM_FLAG  10302.0  2.700000e-01  4.400000e-01      0.0          0.0
#
#                     50%          75%          max
# ID          497004293.0  739455069.0  999926368.0
# KIDSDRIV            0.0          0.0          4.0
# AGE                45.0         51.0         81.0
# HOMEKIDS            0.0          1.0          5.0
# YOJ                11.0         13.0         23.0
# TRAVTIME           33.0         44.0        142.0
# TIF                 4.0          7.0         25.0
# CLM_FREQ            0.0          2.0          5.0
# MVR_PTS             1.0          3.0         13.0
# CAR_AGE             8.0         12.0         28.0
# CLAIM_FLAG          0.0          1.0          1.0

# %%
round(df.corr(),2)
# Out:
#               ID  KIDSDRIV   AGE  HOMEKIDS   YOJ  TRAVTIME   TIF  CLM_FREQ  \
# ID          1.00      0.00 -0.01      0.01 -0.01     -0.00 -0.01     -0.00
# KIDSDRIV    0.00      1.00 -0.08      0.46  0.04      0.01 -0.01      0.04
# AGE        -0.01     -0.08  1.00     -0.45  0.14     -0.00 -0.00     -0.04
# HOMEKIDS    0.01      0.46 -0.45      1.00  0.08     -0.00  0.01      0.04
# YOJ        -0.01      0.04  0.14      0.08  1.00     -0.02  0.02     -0.02
# TRAVTIME   -0.00      0.01 -0.00     -0.00 -0.02      1.00 -0.01      0.01
# TIF        -0.01     -0.01 -0.00      0.01  0.02     -0.01  1.00     -0.02
# CLM_FREQ   -0.00      0.04 -0.04      0.04 -0.02      0.01 -0.02      1.00
# MVR_PTS     0.01      0.05 -0.08      0.06 -0.04      0.01 -0.03      0.40
# CAR_AGE    -0.00     -0.06  0.18     -0.16  0.06     -0.03  0.01     -0.02
# CLAIM_FLAG -0.01      0.11 -0.11      0.12 -0.07      0.05 -0.08      0.22
#
#             MVR_PTS  CAR_AGE  CLAIM_FLAG
# ID             0.01    -0.00       -0.01
# KIDSDRIV       0.05    -0.06        0.11
# AGE           -0.08     0.18       -0.11
# HOMEKIDS       0.06    -0.16        0.12
# YOJ           -0.04     0.06       -0.07
# TRAVTIME       0.01    -0.03        0.05
# TIF           -0.03     0.01       -0.08
# CLM_FREQ       0.40    -0.02        0.22
# MVR_PTS        1.00    -0.03        0.22
# CAR_AGE       -0.03     1.00       -0.11
# CLAIM_FLAG     0.22    -0.11        1.00

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(50,50))
sns.boxplot(df['AGE'],df['CLAIM_FLAG'])
# Out:
# D:\programing app\put\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AGE', ylabel='CLAIM_FLAG'>

# %%
df['CLAIM_FLAG'] = df['CLAIM_FLAG'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10302 entries, 0 to 10301
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10302 non-null  int64
#  1   KIDSDRIV    10302 non-null  int64
#  2   BIRTH       10302 non-null  object
#  3   AGE         10295 non-null  float64
#  4   HOMEKIDS    10302 non-null  int64
#  5   YOJ         9754 non-null   float64
#  6   INCOME      9732 non-null   object
#  7   PARENT1     10302 non-null  object
#  8   HOME_VAL    9727 non-null   object
#  9   MSTATUS     10302 non-null  object
#  10  GENDER      10302 non-null  object
#  11  EDUCATION   10302 non-null  object
#  12  OCCUPATION  9637 non-null   object
#  13  TRAVTIME    10302 non-null  int64
#  14  CAR_USE     10302 non-null  object
#  15  BLUEBOOK    10302 non-null  object
#  16  TIF         10302 non-null  int64
#  17  CAR_TYPE    10302 non-null  object
#  18  RED_CAR     10302 non-null  object
#  19  OLDCLAIM    10302 non-null  object
#  20  CLM_FREQ    10302 non-null  int64
#  21  REVOKED     10302 non-null  object
#  22  MVR_PTS     10302 non-null  int64
#  23  CLM_AMT     10302 non-null  object
#  24  CAR_AGE     9663 non-null   float64
#  25  CLAIM_FLAG  10302 non-null  float64
#  26  URBANICITY  10302 non-null  object
# dtypes: float64(4), int64(7), object(16)
# memory usage: 2.1+ MB

# %%
sns.histplot(data = df, x = 'AGE', hue = 'CLAIM_FLAG')
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Count'>

# %% [markdown]
# # Data Cleaning

# %%
df.drop('BIRTH', axis = 1, inplace = True)
df.isna().sum()
# Out:
# ID              0
# KIDSDRIV        0
# AGE             7
# HOMEKIDS        0
# YOJ           548
# INCOME        570
# PARENT1         0
# HOME_VAL      575
# MSTATUS         0
# GENDER          0
# EDUCATION       0
# OCCUPATION    665
# TRAVTIME        0
# CAR_USE         0
# BLUEBOOK        0
# TIF             0
# CAR_TYPE        0
# RED_CAR         0
# OLDCLAIM        0
# CLM_FREQ        0
# REVOKED         0
# MVR_PTS         0
# CLM_AMT         0
# CAR_AGE       639
# CLAIM_FLAG      0
# URBANICITY      0
# dtype: int64

# %%
DF = df.dropna(subset = ['INCOME'], how = 'any')
DF = DF.dropna(subset = ['HOME_VAL'], how = 'any')
DF.isna().sum()
# Out:
# ID              0
# KIDSDRIV        0
# AGE             4
# HOMEKIDS        0
# YOJ           488
# INCOME          0
# PARENT1         0
# HOME_VAL        0
# MSTATUS         0
# GENDER          0
# EDUCATION       0
# OCCUPATION    584
# TRAVTIME        0
# CAR_USE         0
# BLUEBOOK        0
# TIF             0
# CAR_TYPE        0
# RED_CAR         0
# OLDCLAIM        0
# CLM_FREQ        0
# REVOKED         0
# MVR_PTS         0
# CLM_AMT         0
# CAR_AGE       563
# CLAIM_FLAG      0
# URBANICITY      0
# dtype: int64

# %%
DF.shape
# Out:
# (9197, 26)

# %%
from decimal import Decimal
from re import sub

# %%
def convertMoney(x):
  value = Decimal(sub(r'[^\d.]', '', x))
  return value

# %%
DF['Income_converted'] = DF['INCOME'].apply(lambda x: convertMoney(x))
DF['HOME_VAL_converted'] = DF['HOME_VAL'].apply(lambda x: convertMoney(x))
DF['BLUEBOOK_converted'] = DF['BLUEBOOK'].apply(lambda x: convertMoney(x))
DF['OLDCLAIM_converted'] = DF['OLDCLAIM'].apply(lambda x: convertMoney(x))
DF['CLM_AMT_converted'] = DF['CLM_AMT'].apply(lambda x: convertMoney(x))
DF.head()
# Out:
#           ID  KIDSDRIV   AGE  HOMEKIDS   YOJ    INCOME PARENT1  HOME_VAL  \
# 0   63581743         0  60.0         0  11.0   $67,349      No        $0
# 1  132761049         0  43.0         0  11.0   $91,449      No  $257,252
# 2  921317019         0  48.0         0  11.0   $52,881      No        $0
# 3  727598473         0  35.0         1  10.0   $16,039      No  $124,191
# 5  743146596         0  50.0         0   NaN  $114,986      No  $243,925
#
#   MSTATUS GENDER  ... MVR_PTS CLM_AMT  CAR_AGE CLAIM_FLAG  \
# 0    z_No      M  ...       3      $0     18.0        0.0
# 1    z_No      M  ...       0      $0      1.0        0.0
# 2    z_No      M  ...       2      $0     10.0        0.0
# 3     Yes    z_F  ...       3      $0     10.0        0.0
# 5     Yes    z_F  ...       3      $0     17.0        0.0
#
#             URBANICITY  Income_converted HOME_VAL_converted  \
# 0  Highly Urban/ Urban             67349                  0
# 1  Highly Urban/ Urban             91449             257252
# 2  Highly Urban/ Urban             52881                  0
# 3  Highly Urban/ Urban             16039             124191
# 5  Highly Urban/ Urban            114986             243925
#
#   BLUEBOOK_converted OLDCLAIM_converted  CLM_AMT_converted
# 0              14230               4461                  0
# 1              14940                  0                  0
# 2              21970                  0                  0
# 3               4010              38690                  0
# 5              18000              19217                  0
#
# [5 rows x 31 columns]

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9197 entries, 0 to 10301
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  9197 non-null   int64
#  1   KIDSDRIV            9197 non-null   int64
#  2   AGE                 9193 non-null   float64
#  3   HOMEKIDS            9197 non-null   int64
#  4   YOJ                 8709 non-null   float64
#  5   INCOME              9197 non-null   object
#  6   PARENT1             9197 non-null   object
#  7   HOME_VAL            9197 non-null   object
#  8   MSTATUS             9197 non-null   object
#  9   GENDER              9197 non-null   object
#  10  EDUCATION           9197 non-null   object
#  11  OCCUPATION          8613 non-null   object
#  12  TRAVTIME            9197 non-null   int64
#  13  CAR_USE             9197 non-null   object
#  14  BLUEBOOK            9197 non-null   object
#  15  TIF                 9197 non-null   int64
#  16  CAR_TYPE            9197 non-null   object
#  17  RED_CAR             9197 non-null   object
#  18  OLDCLAIM            9197 non-null   object
#  19  CLM_FREQ            9197 non-null   int64
#  20  REVOKED             9197 non-null   object
#  21  MVR_PTS             9197 non-null   int64
#  22  CLM_AMT             9197 non-null   object
#  23  CAR_AGE             8634 non-null   float64
#  24  CLAIM_FLAG          9197 non-null   float64
#  25  URBANICITY          9197 non-null   object
#  26  Income_converted    9197 non-null   object
#  27  HOME_VAL_converted  9197 non-null   object
#  28  BLUEBOOK_converted  9197 non-null   object
#  29  OLDCLAIM_converted  9197 non-null   object
#  30  CLM_AMT_converted   9197 non-null   object
# dtypes: float64(4), int64(7), object(20)
# memory usage: 2.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10302 entries, 0 to 10301
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10302 non-null  int64
#  1   KIDSDRIV    10302 non-null  int64
#  2   AGE         10295 non-null  float64
#  3   HOMEKIDS    10302 non-null  int64
#  4   YOJ         9754 non-null   float64
#  5   INCOME      9732 non-null   object
#  6   PARENT1     10302 non-null  object
#  7   HOME_VAL    9727 non-null   object
#  8   MSTATUS     10302 non-null  object
#  9   GENDER      10302 non-null  object
#  10  EDUCATION   10302 non-null  object
#  11  OCCUPATION  9637 non-null   object
#  12  TRAVTIME    10302 non-null  int64
#  13  CAR_USE     10302 non-null  object
#  14  BLUEBOOK    10302 non-null  object
#  15  TIF         10302 non-null  int64
#  16  CAR_TYPE    10302 non-null  object
#  17  RED_CAR     10302 non-null  object
#  18  OLDCLAIM    10302 non-null  object
#  19  CLM_FREQ    10302 non-null  int64
#  20  REVOKED     10302 non-null  object
#  21  MVR_PTS     10302 non-null  int64
#  22  CLM_AMT     10302 non-null  object
#  23  CAR_AGE     9663 non-null   float64
#  24  CLAIM_FLAG  10302 non-null  float64
#  25  URBANICITY  10302 non-null  object
# dtypes: float64(4), int64(7), object(15)
# memory usage: 2.0+ MB

# %%
DF['Income_converted'] = DF['Income_converted'].astype('float64')
DF['HOME_VAL_converted'] = DF['HOME_VAL_converted'].astype('float64')
DF['BLUEBOOK_converted'] = DF['BLUEBOOK_converted'].astype('float64')
DF['OLDCLAIM_converted'] = DF['OLDCLAIM_converted'].astype('float64')
DF['CLM_AMT_converted'] = DF['CLM_AMT_converted'].astype('float64')

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9197 entries, 0 to 10301
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  9197 non-null   int64
#  1   KIDSDRIV            9197 non-null   int64
#  2   AGE                 9193 non-null   float64
#  3   HOMEKIDS            9197 non-null   int64
#  4   YOJ                 8709 non-null   float64
#  5   INCOME              9197 non-null   object
#  6   PARENT1             9197 non-null   object
#  7   HOME_VAL            9197 non-null   object
#  8   MSTATUS             9197 non-null   object
#  9   GENDER              9197 non-null   object
#  10  EDUCATION           9197 non-null   object
#  11  OCCUPATION          8613 non-null   object
#  12  TRAVTIME            9197 non-null   int64
#  13  CAR_USE             9197 non-null   object
#  14  BLUEBOOK            9197 non-null   object
#  15  TIF                 9197 non-null   int64
#  16  CAR_TYPE            9197 non-null   object
#  17  RED_CAR             9197 non-null   object
#  18  OLDCLAIM            9197 non-null   object
#  19  CLM_FREQ            9197 non-null   int64
#  20  REVOKED             9197 non-null   object
#  21  MVR_PTS             9197 non-null   int64
#  22  CLM_AMT             9197 non-null   object
#  23  CAR_AGE             8634 non-null   float64
#  24  CLAIM_FLAG          9197 non-null   float64
#  25  URBANICITY          9197 non-null   object
#  26  Income_converted    9197 non-null   float64
#  27  HOME_VAL_converted  9197 non-null   float64
#  28  BLUEBOOK_converted  9197 non-null   float64
#  29  OLDCLAIM_converted  9197 non-null   float64
#  30  CLM_AMT_converted   9197 non-null   float64
# dtypes: float64(9), int64(7), object(15)
# memory usage: 2.2+ MB

# %%
DF1 = DF.drop(['INCOME', 'HOME_VAL', 'BLUEBOOK', 'OLDCLAIM', 'CLM_AMT'], axis = 1)
DF1.head()
# Out:
#           ID  KIDSDRIV   AGE  HOMEKIDS   YOJ PARENT1 MSTATUS GENDER  \
# 0   63581743         0  60.0         0  11.0      No    z_No      M
# 1  132761049         0  43.0         0  11.0      No    z_No      M
# 2  921317019         0  48.0         0  11.0      No    z_No      M
# 3  727598473         0  35.0         1  10.0      No     Yes    z_F
# 5  743146596         0  50.0         0   NaN      No     Yes    z_F
#
#        EDUCATION     OCCUPATION  ...  REVOKED MVR_PTS  CAR_AGE CLAIM_FLAG  \
# 0            PhD   Professional  ...       No       3     18.0        0.0
# 1  z_High School  z_Blue Collar  ...       No       0      1.0        0.0
# 2      Bachelors        Manager  ...       No       2     10.0        0.0
# 3  z_High School       Clerical  ...       No       3     10.0        0.0
# 5            PhD         Doctor  ...      Yes       3     17.0        0.0
#
#             URBANICITY  Income_converted HOME_VAL_converted  \
# 0  Highly Urban/ Urban           67349.0                0.0
# 1  Highly Urban/ Urban           91449.0           257252.0
# 2  Highly Urban/ Urban           52881.0                0.0
# 3  Highly Urban/ Urban           16039.0           124191.0
# 5  Highly Urban/ Urban          114986.0           243925.0
#
#    BLUEBOOK_converted  OLDCLAIM_converted  CLM_AMT_converted
# 0             14230.0              4461.0                0.0
# 1             14940.0                 0.0                0.0
# 2             21970.0                 0.0                0.0
# 3              4010.0             38690.0                0.0
# 5             18000.0             19217.0                0.0
#
# [5 rows x 26 columns]

# %%
sns.set_theme()
sns.barplot(data = DF1,x = 'EDUCATION', y = 'Income_converted', label = 'CLAIM_FLAG')
# Out:
# <AxesSubplot:xlabel='EDUCATION', ylabel='Income_converted'>

# %%
sns.histplot(data = DF1, x = 'Income_converted', hue = 'CLAIM_FLAG')
# Out:
# <AxesSubplot:xlabel='Income_converted', ylabel='Count'>

# %%
# drops - 'BIRTH', 'INCOME', 'HOME_VAL', 'BLUEBOOK', 'OLDCLAIM', 'CLM_AMT'

# %%
DF1
# Out:
#               ID  KIDSDRIV   AGE  HOMEKIDS   YOJ PARENT1 MSTATUS GENDER  \
# 0       63581743         0  60.0         0  11.0      No    z_No      M
# 1      132761049         0  43.0         0  11.0      No    z_No      M
# 2      921317019         0  48.0         0  11.0      No    z_No      M
# 3      727598473         0  35.0         1  10.0      No     Yes    z_F
# 5      743146596         0  50.0         0   NaN      No     Yes    z_F
# ...          ...       ...   ...       ...   ...     ...     ...    ...
# 10297   67790126         1  45.0         2   9.0      No     Yes      M
# 10298   61970712         0  46.0         0   9.0      No     Yes      M
# 10299  849208064         0  48.0         0  15.0      No     Yes    z_F
# 10300  627828331         0  50.0         0   7.0      No     Yes    z_F
# 10301  680381960         0  52.0         0  11.0      No     Yes    z_F
#
#            EDUCATION     OCCUPATION  ...  REVOKED MVR_PTS  CAR_AGE CLAIM_FLAG  \
# 0                PhD   Professional  ...       No       3     18.0        0.0
# 1      z_High School  z_Blue Collar  ...       No       0      1.0        0.0
# 2          Bachelors        Manager  ...       No       2     10.0        0.0
# 3      z_High School       Clerical  ...       No       3     10.0        0.0
# 5                PhD         Doctor  ...      Yes       3     17.0        0.0
# ...              ...            ...  ...      ...     ...      ...        ...
# 10297            PhD        Manager  ...       No       2     17.0        0.0
# 10298        Masters            NaN  ...       No       0      1.0        0.0
# 10299   <High School  z_Blue Collar  ...       No       0      1.0        0.0
# 10300      Bachelors     Home Maker  ...       No       0     11.0        0.0
# 10301  z_High School       Clerical  ...       No       0      9.0        0.0
#
#                   URBANICITY  Income_converted HOME_VAL_converted  \
# 0        Highly Urban/ Urban           67349.0                0.0
# 1        Highly Urban/ Urban           91449.0           257252.0
# 2        Highly Urban/ Urban           52881.0                0.0
# 3        Highly Urban/ Urban           16039.0           124191.0
# 5        Highly Urban/ Urban          114986.0           243925.0
# ...                      ...               ...                ...
# 10297    Highly Urban/ Urban          164669.0           386273.0
# 10298    Highly Urban/ Urban          107204.0           332591.0
# 10299    Highly Urban/ Urban           39837.0           170611.0
# 10300    Highly Urban/ Urban           43445.0           149248.0
# 10301  z_Highly Rural/ Rural           53235.0           197017.0
#
#        BLUEBOOK_converted  OLDCLAIM_converted  CLM_AMT_converted
# 0                 14230.0              4461.0                0.0
# 1                 14940.0                 0.0                0.0
# 2                 21970.0                 0.0                0.0
# 3                  4010.0             38690.0                0.0
# 5                 18000.0             19217.0                0.0
# ...                   ...                 ...                ...
# 10297             13270.0                 0.0                0.0
# 10298             24490.0                 0.0                0.0
# 10299             13820.0                 0.0                0.0
# 10300             22550.0                 0.0                0.0
# 10301             19400.0                 0.0                0.0
#
# [9197 rows x 26 columns]

# %%
from scipy import stats

# %%
DF1['AGE'].fillna(np.median(DF1['AGE']), inplace = True)
DF1['YOJ'].fillna(stats.mode(DF1['YOJ'])[0][0], inplace = True)
DF1['OCCUPATION'].fillna(stats.mode(DF1['OCCUPATION'])[0][0], inplace = True)
DF1['CAR_AGE'].fillna(stats.mode(DF1['CAR_AGE'])[0][0], inplace = True)
#DF1['AGE'].unique()
DF1 = DF1.dropna(how = 'any')
# Out:
# D:\programing app\put\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
DF1
# Out:
#               ID  KIDSDRIV   AGE  HOMEKIDS   YOJ PARENT1 MSTATUS GENDER  \
# 0       63581743         0  60.0         0  11.0      No    z_No      M
# 1      132761049         0  43.0         0  11.0      No    z_No      M
# 2      921317019         0  48.0         0  11.0      No    z_No      M
# 3      727598473         0  35.0         1  10.0      No     Yes    z_F
# 5      743146596         0  50.0         0  12.0      No     Yes    z_F
# ...          ...       ...   ...       ...   ...     ...     ...    ...
# 10297   67790126         1  45.0         2   9.0      No     Yes      M
# 10298   61970712         0  46.0         0   9.0      No     Yes      M
# 10299  849208064         0  48.0         0  15.0      No     Yes    z_F
# 10300  627828331         0  50.0         0   7.0      No     Yes    z_F
# 10301  680381960         0  52.0         0  11.0      No     Yes    z_F
#
#            EDUCATION     OCCUPATION  ...  REVOKED MVR_PTS  CAR_AGE CLAIM_FLAG  \
# 0                PhD   Professional  ...       No       3     18.0        0.0
# 1      z_High School  z_Blue Collar  ...       No       0      1.0        0.0
# 2          Bachelors        Manager  ...       No       2     10.0        0.0
# 3      z_High School       Clerical  ...       No       3     10.0        0.0
# 5                PhD         Doctor  ...      Yes       3     17.0        0.0
# ...              ...            ...  ...      ...     ...      ...        ...
# 10297            PhD        Manager  ...       No       2     17.0        0.0
# 10298        Masters  z_Blue Collar  ...       No       0      1.0        0.0
# 10299   <High School  z_Blue Collar  ...       No       0      1.0        0.0
# 10300      Bachelors     Home Maker  ...       No       0     11.0        0.0
# 10301  z_High School       Clerical  ...       No       0      9.0        0.0
#
#                   URBANICITY  Income_converted HOME_VAL_converted  \
# 0        Highly Urban/ Urban           67349.0                0.0
# 1        Highly Urban/ Urban           91449.0           257252.0
# 2        Highly Urban/ Urban           52881.0                0.0
# 3        Highly Urban/ Urban           16039.0           124191.0
# 5        Highly Urban/ Urban          114986.0           243925.0
# ...                      ...               ...                ...
# 10297    Highly Urban/ Urban          164669.0           386273.0
# 10298    Highly Urban/ Urban          107204.0           332591.0
# 10299    Highly Urban/ Urban           39837.0           170611.0
# 10300    Highly Urban/ Urban           43445.0           149248.0
# 10301  z_Highly Rural/ Rural           53235.0           197017.0
#
#        BLUEBOOK_converted  OLDCLAIM_converted  CLM_AMT_converted
# 0                 14230.0              4461.0                0.0
# 1                 14940.0                 0.0                0.0
# 2                 21970.0                 0.0                0.0
# 3                  4010.0             38690.0                0.0
# 5                 18000.0             19217.0                0.0
# ...                   ...                 ...                ...
# 10297             13270.0                 0.0                0.0
# 10298             24490.0                 0.0                0.0
# 10299             13820.0                 0.0                0.0
# 10300             22550.0                 0.0                0.0
# 10301             19400.0                 0.0                0.0
#
# [9193 rows x 26 columns]

# %%
DF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9193 entries, 0 to 10301
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  9193 non-null   int64
#  1   KIDSDRIV            9193 non-null   int64
#  2   AGE                 9193 non-null   float64
#  3   HOMEKIDS            9193 non-null   int64
#  4   YOJ                 9193 non-null   float64
#  5   PARENT1             9193 non-null   object
#  6   MSTATUS             9193 non-null   object
#  7   GENDER              9193 non-null   object
#  8   EDUCATION           9193 non-null   object
#  9   OCCUPATION          9193 non-null   object
#  10  TRAVTIME            9193 non-null   int64
#  11  CAR_USE             9193 non-null   object
#  12  TIF                 9193 non-null   int64
#  13  CAR_TYPE            9193 non-null   object
#  14  RED_CAR             9193 non-null   object
#  15  CLM_FREQ            9193 non-null   int64
#  16  REVOKED             9193 non-null   object
#  17  MVR_PTS             9193 non-null   int64
#  18  CAR_AGE             9193 non-null   float64
#  19  CLAIM_FLAG          9193 non-null   float64
#  20  URBANICITY          9193 non-null   object
#  21  Income_converted    9193 non-null   float64
#  22  HOME_VAL_converted  9193 non-null   float64
#  23  BLUEBOOK_converted  9193 non-null   float64
#  24  OLDCLAIM_converted  9193 non-null   float64
#  25  CLM_AMT_converted   9193 non-null   float64
# dtypes: float64(9), int64(7), object(10)
# memory usage: 1.9+ MB

# %%
DF1.isna().sum()
# Out:
# ID                    0
# KIDSDRIV              0
# AGE                   0
# HOMEKIDS              0
# YOJ                   0
# PARENT1               0
# MSTATUS               0
# GENDER                0
# EDUCATION             0
# OCCUPATION            0
# TRAVTIME              0
# CAR_USE               0
# TIF                   0
# CAR_TYPE              0
# RED_CAR               0
# CLM_FREQ              0
# REVOKED               0
# MVR_PTS               0
# CAR_AGE               0
# CLAIM_FLAG            0
# URBANICITY            0
# Income_converted      0
# HOME_VAL_converted    0
# BLUEBOOK_converted    0
# OLDCLAIM_converted    0
# CLM_AMT_converted     0
# dtype: int64

# %%
DF1.shape
# Out:
# (9193, 26)
